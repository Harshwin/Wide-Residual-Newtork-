# %%
import numpy as np

# %%
vals = np.load('./epochs_values.npy')

# %%
import pandas as pd
pd.DataFrame(vals)
# Out:
#            0       1
# 0   0.060256  0.1115
# 1   0.135828  0.2050
# 2   0.210619  0.2746
# 3   0.276247  0.3486
# 4   0.335659  0.4194
# 5   0.380394  0.4665
# 6   0.421599  0.4912
# 7   0.458153  0.5210
# 8   0.491077  0.5451
# 9   0.513555  0.5612
# 10  0.541506  0.5888
# 11  0.560956  0.5935
# 12  0.581509  0.6028
# 13  0.598151  0.6075
# 14  0.619205  0.6243
# 15  0.636189  0.6328
# 16  0.648320  0.6244
# 17  0.660471  0.6438
# 18  0.675108  0.6442
# 19  0.686878  0.6496
# 20  0.701416  0.6515
# 21  0.708795  0.6572
# 22  0.726319  0.6631
# 23  0.733077  0.6607
# 24  0.746291  0.6702
# 25  0.749980  0.6675
# 26  0.763354  0.6636
# 27  0.769991  0.6661
# 28  0.783426  0.6770
# 29  0.787837  0.6681
# ..       ...     ...
# 62  0.896114  0.6935
# 63  0.898781  0.6993
# 64  0.903393  0.7027
# 65  0.908205  0.7036
# 66  0.908626  0.6976
# 67  0.913338  0.6968
# 68  0.911092  0.6897
# 69  0.916827  0.6900
# 70  0.915564  0.6955
# 71  0.922121  0.7022
# 72  0.920015  0.6985
# ...
